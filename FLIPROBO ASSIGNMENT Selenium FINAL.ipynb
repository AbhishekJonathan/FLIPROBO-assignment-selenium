# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
# QUESTION 1 first Connect to driver
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
# opening Naukari.com in automated web browser
driver.get(" https://www.naukri.com/")

# %%
# Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the location” field.

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input" )
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
Job_title=[]
Job_location=[]
company_name=[]
experience_required=[]

# %%
# scrapping job title from the given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    Job_title.append(title)
    
#scraping location from given page
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    Job_location.append(location)
    
    
# Scraping company name from given page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
# Scraping experience from given page
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(Job_title),len( Job_location),len(company_name),len( experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':Job_title,'Location':Job_location,'Company':company_name,'Experience':experience_required})
df
# Out:
#                               Title  \
# 0         Data Analyst- Yulu Energy
# 1                      Data Analyst
# 2                      Data Analyst
# 3           Data Analyst Databricks
# 4                      Data Analyst
# 5                      Data Analyst
# 6    Required Data Analyst Off Role
# 7  Data Analyst | Google App Script
# 8                      Data Analyst
# 9                      Data Analyst
#
#                                             Location  \
# 0                                Bangalore/Bengaluru
# 1                                Bangalore/Bengaluru
# 2  Hybrid - Bangalore/Bengaluru, Hyderabad/Secund...
# 3                                Bangalore/Bengaluru
# 4                       Hybrid - Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# 6                                Bangalore/Bengaluru
# 7                        Bangalore/Bengaluru, Mumbai
# 8                                Bangalore/Bengaluru
# ...

# %%
# QUESTION 2 :Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
driver.get(' https://www.naukri.com/')

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
Job_name=[]
Job_location=[]
company_name=[]
experience_required=[]

# %%
Jobname_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in Jobname_tags[0:10]:
    Jobname=i.text
    Job_name.append(Jobname)
    
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    Job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(Job_name),len(Job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':Job_name,'Location':Job_location,'Organization':company_name,'Experience':experience_required})
df
# Out:
#                               Title  \
# 0           Data Science Specialist
# 1  Analystics & Modeling Specialist
# 2                    Data Scientist
# 3                Sr. Data scientist
# 4                    Data Scientist
# 5               Lead Data Scientist
# 6                    Data Scientist
# 7             Expert Data Scientist
# 8                Sr. Data Scientist
# 9          Data Scientist Architect
#
#                                             Location  \
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 2  Hybrid - Bangalore/Bengaluru, Kolkata, Hyderab...
# 3  Bangalore/Bengaluru, Hyderabad/Secunderabad, M...
# 4  Bangalore/Bengaluru, Noida, Kolkata, Mumbai, H...
# 5  Bangalore/Bengaluru, Noida, Hyderabad/Secunder...
# 6  Bangalore/Bengaluru, Noida, Indore, Pune, Gurg...
# 7                        Bangalore/Bengaluru, Mumbai
# 8                                Bangalore/Bengaluru
# ...

# %%
#:QUESTION 3 In this question you have to scrape data using the filters available on the webpage as shown below:

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
driver.get(' https://www.naukri.com/')

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Scientist')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
Job_name=[]
Job_location=[]
Salary=[]
company_name=[]
experience_required=[]

# %%
Jobname_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in Jobname_tags[0:10]:
    Jobname=i.text
    Job_name.append(Jobname)
    
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    Job_location.append(location)
    
salary_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft "]')
for i in salary_tags[0:10]:
    salary=i.text
    Salary.append(salary)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(Job_name),len(Job_location),len(Salary),len(company_name),len(experience_required))
# Out:
# 10 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':Job_name,'Location':Job_location,'SALARY':Salary,'Organization':company_name,'Experience':experience_required})
df
# Out:
#                                  Title  \
# 0          Data Scientist data Analyst
# 1    Data Scientist - Engine Algorithm
# 2                 Analyst-Data Science
# 3                 Analyst-Data Science
# 4   Senior Data Scientist - Statistics
# 5                       Data Scientist
# 6                       Data Scientist
# 7  Associate Data Scientist - ML & NLP
# 8                       Data Scientist
# 9                       Data Scientist
#
#                                             Location  \
# 0  Delhi / NCR, Kolkata, Hyderabad/Secunderabad, ...
# 1  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 2                                   Gurgaon/Gurugram
# 3                                   Gurgaon/Gurugram
# 4                                   Gurgaon/Gurugram
# 5  Delhi / NCR, Noida(Sector-136 Noida), Ghaziaba...
# 6                                   Gurgaon/Gurugram
# 7                                   Gurgaon/Gurugram
# ...

# %%
# QUESTION 4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/')

# %%
search_products=driver.find_element(By.CLASS_NAME,"_3704LK")
search_products.send_keys('sunglasses')

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
Brand_name=[]
product_description=[]
price=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:40]:
    name=i.text
    Brand_name.append(name)
    
product_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in product_tags[0:40]:
    descp=i.text
    product_description.append(descp)
    
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags[0:40]:
    pri=i.text
    price.append(pri)

# %%
print(len(brand_tags),len(product_description),len(price))
# Out:
# 40 40 40

# %%
import pandas as pd
df=pd.DataFrame({'BRAND NAME':Brand_name,'PRODUCT DESCP':product_description,'PRICE':price})
df
# Out:
#            BRAND NAME                                      PRODUCT DESCP PRICE
# 0       VINCENT CHASE     Polarized, UV Protection Round Sunglasses (50)  ₹829
# 1      ROZZETTA CRAFT              UV Protection Aviator Sunglasses (55)  ₹649
# 2                SRPM             UV Protection Wayfarer Sunglasses (50)  ₹149
# 3           Elligator                UV Protection Round Sunglasses (53)  ₹149
# 4            Fastrack   UV Protection Rectangular Sunglasses (Free Size)  ₹599
# 5           Elligator             UV Protection Wayfarer Sunglasses (53)  ₹149
# 6           Elligator                UV Protection Round Sunglasses (54)  ₹229
# 7       VINCENT CHASE  by Lenskart Polarized, UV Protection Retro Squ...  ₹999
# 8              PIRASO              UV Protection Aviator Sunglasses (58)  ₹274
# 9            Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...  ₹489
# 10          Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...  ₹149
# ...

# %%
Brand_name=[]
product_description=[]
price=[]

# %%
start=0
end=5
for i in range(start,end):
    name=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in name[0:20]:
        Brand_name.append(i.text)
for i in range(start,end):
    description=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in description[0:20]:
        product_description.append(i.text)
        
for i in range(start,end):
    pri=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in pri[0:20]:
        price.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="ge-49M"]')
    next_button.click()
    time.sleep(3)

# %%
len(Brand_name)
# Out:
# 100

# %%
len(product_description)
# Out:
# 100

# %%
len(price)
# Out:
# 100

# %%
import pandas as pd
df1=pd.DataFrame({'Brand':Brand_name,'PRODUCT DESCP':product_description,'PRICE':price})
df1
# Out:
#              Brand                                      PRODUCT DESCP PRICE
# 0    VINCENT CHASE     Polarized, UV Protection Round Sunglasses (50)  ₹829
# 1   ROZZETTA CRAFT              UV Protection Aviator Sunglasses (55)  ₹649
# 2             SRPM             UV Protection Wayfarer Sunglasses (50)  ₹149
# 3        Elligator                UV Protection Round Sunglasses (53)  ₹149
# 4         Fastrack   UV Protection Rectangular Sunglasses (Free Size)  ₹599
# ..             ...                                                ...   ...
# 95   VINCENT CHASE  by Lenskart Polarized, UV Protection Cat-eye S...  ₹599
# 96          PIRASO              UV Protection Aviator Sunglasses (54)  ₹208
# 97        Fastrack       UV Protection Aviator Sunglasses (Free Size)  ₹599
# 98       New Specs   UV Protection Rectangular Sunglasses (Free Size)  ₹259
# 99   VINCENT CHASE  by Lenskart Polarized, UV Protection Aviator S...  ₹745
#
# [100 rows x 3 columns]

# %%
# Question 5 : Scrape 100 reviews data from flipkart.com for iphone11 phone.

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market')

# %%
rating=[]
reveiw_summary=[]
full_reveiw=[]

# %%
rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tags[0:10]:
    rate=i.text
    rating.append(rate)
    
reveiw_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in reveiw_tags[0:10]:
    rev=i.text
    reveiw_summary.append(rev)
    
full_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in full_tags[0:10]:
    full=i.text
    full_reveiw.append(full)

# %%
print(len(rating),len(reveiw_summary),len(full_reveiw))
# Out:
# 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'RATINGS':rating,'REVEIW':reveiw_summary,'FULLREVEIW':full_reveiw})
df
# Out:
#   RATINGS               REVEIW  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3       4      Value-for-money
# 4       5   Highly recommended
# 5       5    Worth every penny
# 6       5     Perfect product!
# 7       5   Highly recommended
# 8       4          Pretty good
# 9       5        Great product
#
#                                           FULLREVEIW
# 0  Really satisfied with the Product I received.....
# 1  Amazing phone with great cameras and better ba...
# 2  Great iPhone very snappy experience as apple k...
# 3  I'm Really happy with the product\nDelivery wa...
# 4  It's my first time to use iOS phone and I am l...
# 5  Previously I was using one plus 3t it was a gr...
# 6  Value for money\n5 star rating\nExcellent came...
# 7  What a camera .....just awesome ..you can feel...
# 8  I was using Iphone 6s and also Oneplus 6t. Bot...
# 9  Amazing Powerful and Durable Gadget.\n\nI’m am...

# %%
rating=[]
reveiw_summary=[]
full_reveiw=[]

# %%
start=0
end=10
for i in range(start,end):
    tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in tags[0:10]:
        rating.append(i.text)
for i in range(start,end):
    Rev=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in Rev[0:10]:
        reveiw_summary.append(i.text)
        
for i in range(start,end):
    reveiw=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in reveiw[0:10]:
        full_reveiw.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="ge-49M"]')
    next_button.click()
    time.sleep(3)

# %%
print(len(rating),len(reveiw_summary),len(full_reveiw))
# Out:
# 100 100 100

# %%
import pandas as pd
df=pd.DataFrame({'RATING':rating,'Reveiw_summary':reveiw_summary,'Full_reveiw':full_reveiw})
df
# Out:
#    RATING       Reveiw_summary  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3       4      Value-for-money
# 4       5   Highly recommended
# ..    ...                  ...
# 95      5    Worth every penny
# 96      5     Perfect product!
# 97      5   Highly recommended
# 98      4          Pretty good
# 99      5        Great product
#
#                                           Full_reveiw
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   I'm Really happy with the product\nDelivery wa...
# 4   It's my first time to use iOS phone and I am l...
# ..                                                ...
# 95  Previously I was using one plus 3t it was a gr...
# 96  Value for money\n5 star rating\nExcellent came...
# 97  What a camera .....just awesome ..you can feel...
# ...

# %%
full_reveiw=[]

# %%
start=0
end=10
for i in range(start,end):
    reveiw=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in reveiw[0:10]:
        full_reveiw.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="ge-49M"]')
    next_button.click()
    time.sleep(3)

# %%
print(len(full_reveiw))
# Out:
# 100

# %%
import pandas as pd
df=pd.DataFrame({'Full_reveiw':full_reveiw})
df
# Out:
#                                           Full_reveiw
# 0   This is my first iOS phone. I am very happy wi...
# 1   Best and amazing product.....phone looks so pr...
# 2   i11 is worthy to buy, too much happy with the ...
# 3   It’s a must buy who is looking for an upgrade ...
# 4   Just got this iphone 11\nAnd it is most powerf...
# ..                                                ...
# 95  So far it’s been an AMAZING experience coming ...
# 96  Value for money❤️❤️\nIts awesome mobile phone ...
# 97  iphone 11 is a very good phone to buy only if ...
# 98  Amazing camera quality as expected, battery al...
# 99  It is just awesome mobile for this price from ...
#
# [100 rows x 1 columns]

# %%
#Question 6:Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
search=driver.find_element(By.CLASS_NAME,"_3704LK")
search.send_keys('Sneakers')

# %%
tap=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
tap.click()

# %%
Brand=[]
product_description=[]
price=[]

# %%
Brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in Brand_tags[0:38]:
    btags=i.text
    Brand.append(btags)
    
product_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in product_tags[0:38]:
    descp=i.text
    product_description.append(descp)
    
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags[0:38]:
    pri=i.text
    price.append(pri)

# %%
print(len(Brand),len(product_description),len(price))
# Out:
# 38 38 38

# %%
import pandas as pd
df=pd.DataFrame({'BRAND':Brand,'PRODUCT_DESP':product_description,'PRICE':price})
df
# Out:
#            BRAND                                       PRODUCT_DESP   PRICE
# 0     KNIGHTWING  Latest Design Comfortable Casual Sneakers For Men    ₹699
# 1   K- FOOTLANCE  Smooth Blue Sports,Casual,Walking,Gym Sneakers...    ₹999
# 2           aadi  Synthetic Leather |Lightweight|Comfort|Summer|...    ₹399
# 3         Shozie  Stylish Sneakers Shoes for Women And Girls Sne...    ₹374
# 4          BIRDE      Combo Pack of 2 Casual Shoes Sneakers For Men    ₹499
# 5           aadi  Synthetic Leather |Lightweight|Comfort|Summer|...    ₹399
# 6         Kraasa                                 Sneakers For Women    ₹299
# 7           OZJI  Ankle Laceup Sneaker Color Black Size 6-10, Ca...    ₹487
# 8       BERSACHE  Combo pack of 2 casual shoes for men Sneakers ...    ₹549
# 9         Shozie  Stylish Walking Partywear Sneakers Casual Shoe...    ₹389
# 10        BRUTON             2 Combo Sneaker Shoes Sneakers For Men    ₹499
# ...

# %%
Brand_name=[]
product_description=[]
price=[]

# %%
start=0
end=5
for i in range(start,end):
    name=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in name[0:20]:
        Brand_name.append(i.text)
for i in range(start,end):
    description=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in description[0:20]:
        product_description.append(i.text)
        
for i in range(start,end):
    pri=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in pri[0:20]:
        price.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="ge-49M"]')
    next_button.click()
    time.sleep(3)

# %%
print(len(Brand_name),len(product_description),len(price))
# Out:
# 100 100 100

# %%
import pandas as pd
df=pd.DataFrame({'BRAND':Brand_name,'Product DESCRIPTION':product_description,'Price':price})
df
# Out:
#            BRAND                                Product DESCRIPTION   Price
# 0     KNIGHTWING  Latest Design Comfortable Casual Sneakers For Men    ₹699
# 1   K- FOOTLANCE  Smooth Blue Sports,Casual,Walking,Gym Sneakers...    ₹999
# 2           aadi  Synthetic Leather |Lightweight|Comfort|Summer|...    ₹399
# 3         Shozie  Stylish Sneakers Shoes for Women And Girls Sne...    ₹374
# 4          BIRDE      Combo Pack of 2 Casual Shoes Sneakers For Men    ₹499
# ..           ...                                                ...     ...
# 95          aadi                                   Sneakers For Men    ₹589
# 96        Layasa                                 Sneakers For Women    ₹388
# 97        Shozie                                 Sneakers For Women    ₹299
# 98        Kraasa                          Series 7 Sneakers For Men    ₹599
# 99         Zixer  Exclusive dancing sneaker For Boys||Funky danc...  ₹1,281
#
# [100 rows x 3 columns]

# %%
#Write a python program to scrape data for Top 1000 Quotes of All Time.

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
driver.get('https://www.azquotes.com/')

# %%
quote=[]
author=[]
quote_type=[]

# %%
quote_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in quote_tags[0:100]:
    tags=i.text
    quote.append(tags)
    
author_tags=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_tags[0:100]:
    aut=i.text
    author.append(aut)
    
type_tags=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in type_tags[0:100]:
    Q_t=i.text
    quote_type.append(Q_t)

# %%
print(len(quote),len(author),len(quote_type))
# Out:
# 100 100 100

# %%
import pandas as pd
df=pd.DataFrame({'QUOTE':quote,'AUTHOR':author,'QUOTE_TYPE':quote_type})
df
# Out:
#                                                 QUOTE                AUTHOR  \
# 0   The essence of strategy is choosing what not t...        Michael Porter
# 1   One cannot and must not try to erase the past ...            Golda Meir
# 2   Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3   Death is something inevitable. When a man has ...        Nelson Mandela
# 4   You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                ...                   ...
# 95     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 96  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 97  If you think you are too small to make a diffe...            Dalai Lama
# 98  God doesn't require us to succeed, he only req...         Mother Teresa
# 99    Change your thoughts and you change your world.  Norman Vincent Peale
#
#                                   QUOTE_TYPE
# ...

# %%
# : Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead,Term of office, Remarks)

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
driver.get('https://www.jagranjosh.com/')

# %%
Name=[]
Born_dead=[]
Term_of_office=[]
Remarks=[]

# %%
name_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[3]/table/tbody/tr[2]/td[2]/p')
for i in name_tags[0:17]:
    tags=(i.text)
    Name.append(tags)

# %%
Born_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[3]/table/tbody/tr[2]/td[3]/p')
for i in Born_tags[0:17]:
    Born=(i.text)
    Born_dead.append(Born)

# %%
TOF_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[3]/table/tbody/tr[2]/td[4]/p[1]/span')
for i in TOF_tags[0:17]:
    office=(i.text)
    Term_of_office.append(office)

# %%
Rem_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[3]/table/tbody/tr[2]/td[5]/p')
for i in Rem_tags[0:17]:
    Rema=(i.text)
    Remarks.append(Rema)

# %%
print(len(Name),len(Born_dead),len(Term_of_office),len(Remarks))
# Out:
# 1 1 1 1

# %%
import pandas as pd
df=pd.DataFrame({'NAME':Name,'Born_Dead':Born_dead,' Term_Of_Office': Term_of_office,'REMARKS':Remarks})
df
# Out:
#                 NAME    Born_Dead                 Term_Of_Office  \
# 0  Jawahar Lal Nehru  (1889–1964)  15 August 1947 to 27 May 1964
#
#                                              REMARKS
# 0  The first prime minister of India and the long...

# %%
# Question 10 :Write a python program to display list of 50 Most expensive cars in the world (i.e.Car name and Price)

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
driver.get('https://www.motor1.com/')

# %%
Car_Name=[]
Price=[]

# %%
Car_tags=driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in Car_tags[0:50]:
    Name=(i.text)
    Car_Name.append(Name)
    
    
price_tags=driver.find_elements(By.XPATH,'//p[strong]')
for i in price_tags[0:50]:
    PT=(i.text)
    Price.append(PT)

# %%
print(len(Car_Name),len(Price))
# Out:
# 50 50

# %%
import pandas as pd
df=pd.DataFrame({'CAR':Car_Name,'PRICE':Price})
df
# Out:
#                                 CAR  \
# 0                     De Tomaso P72
# 1                 Ferrari LaFerrari
# 2                     Pagani Huayra
# 3                      McLaren Elva
# 4                       Czinger 21C
# 5                     Ferrari Monza
# 6                Gordon Murray T.33
# 7                 Koenigsegg Gemera
# 8                       Zenvo TSR-S
# 9                Hennessey Venom F5
# 10                  Bentley Bacalar
# 11    Hispano Suiza Carmen Boulogne
# 12           Bentley Mulliner Batur
# 13                     Deus Vayanne
# 14                      SSC Tuatara
# 15                      Lotus Evija
# 16              Aston Martin Vulcan
# 17                       Delage D12
# 18                McLaren Speedtail
# 19                     Rimac Nevera
# 20                    Pagani Utopia
# 21             Pininfarina Battista
# 22                Ferrari FXX K Evo
# 23               Gordon Murray T.50
# 24             Lamborghini Countach
# ...

# %% [markdown]
# # Question 7 : : Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then
# set CPU Type filter to “Intel Core i7”

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
driver.get('https://www.amazon.in/')

# %%
Title=[]
Rating=[]
Price=[]

# %%
Title_tags=driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
for i in Title_tags[0:24]:
    TT=(i.text)
    Title.append(TT)
    
Rating_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-base"]')
for i in Rating_tags[0:24]:
    Rat=(i.text)
    Rating.append(Rat)

# %%
print(len(Title),len(Rating))
# Out:
# 24 24

# %%
import pandas as pd
df=pd.DataFrame({'TITLE':Title,'RATING':Rating})
df
# Out:
#                                                 TITLE RATING
# 0   ASUS Vivobook 14, Intel Core i7-1165G7 11th Ge...    4.1
# 1   HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...    4.0
# 2   HP Victus Gaming Latest 12th Gen Intel Core i7...    4.3
# 3   Samsung Galaxy Book2 (NP750) Intel 12th Gen co...    4.0
# 4   Dell Inspiron 5320 Laptop, Intel i7-1260P, 16G...    3.3
# 5   MSI GF75 Thin Gaming, Intel Core i7-10750H, 44...    4.4
# 6   Hp Pavilion 15 12Th Gen Intel Core I7 16Gb Sdr...    3.8
# 7   ASUS TUF Gaming F15 (2022), 15.6" (39.62 cms) ...    4.0
# 8   ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, I...    4.1
# 9   ASUS TUF Dash F15 (2022), 15.6-inch (39.62 cms...    5.0
# 10  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...    4.3
# 11  (Renewed) Dell Latitude E7470 Intel Core i7 6t...    4.0
# 12  Lenovo IdeaPad Slim 5 12th Gen Intel Core i7 1...    4.2
# 13  HP Pavilion 14 11th Gen Intel Core i7 16GB/1TB...    4.4
# ...
