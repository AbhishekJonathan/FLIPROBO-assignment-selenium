# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
# QUESTION 1 first Connect to driver
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
# opening Naukari.com in automated web browser
driver.get(" https://www.naukri.com/")

# %%
# Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the location” field.

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input" )
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
Job_title=[]
Job_location=[]
company_name=[]
experience_required=[]

# %%
# scrapping job title from the given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    Job_title.append(title)
    
#scraping location from given page
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    Job_location.append(location)
    
    
# Scraping company name from given page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
# Scraping experience from given page
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(Job_title),len( Job_location),len(company_name),len( experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':Job_title,'Location':Job_location,'Company':company_name,'Experience':experience_required})
df
# Out:
#                    Title                                           Location  \
# 0           Data Analyst                                Bangalore/Bengaluru
# 1           Data Analyst  Hybrid - Bangalore/Bengaluru, Hyderabad/Secund...
# 2           Data Analyst                                Bangalore/Bengaluru
# 3           Data Analyst                                Bangalore/Bengaluru
# 4           Data Analyst          Hybrid - Bangalore/Bengaluru, Delhi / NCR
# 5           Data Analyst                                Bangalore/Bengaluru
# 6           Data Analyst                                Bangalore/Bengaluru
# 7  Data Analyst - EdTech                                Bangalore/Bengaluru
# 8           Data Analyst                                Bangalore/Bengaluru
# 9           Data Analyst                                Bangalore/Bengaluru
#
#                        Company Experience
# 0                      Entrupy    1-3 Yrs
# 1                           EY   5-10 Yrs
# ...

# %%
# QUESTION 2 :Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
driver.get(' https://www.naukri.com/')

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
Job_name=[]
Job_location=[]
company_name=[]
experience_required=[]

# %%
Jobname_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in Jobname_tags[0:10]:
    Jobname=i.text
    Job_name.append(Jobname)
    
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    Job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(Job_name),len(Job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':Job_name,'Location':Job_location,'Organization':company_name,'Experience':experience_required})
df
# Out:
#                                              Title  \
# 0                          Data Science Specialist
# 1                 Analystics & Modeling Specialist
# 2                                   Data Scientist
# 3                               Sr. Data scientist
# 4                                   Data Scientist
# 5                            Expert Data Scientist
# 6                              Lead Data Scientist
# 7          Lead Artificial Intelligence Specialist
# 8                              Lead data scientist
# 9  Senior Director/Head - Data Science & Analytics
#
#                                             Location  \
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 2  Hybrid - Bangalore/Bengaluru, Kolkata, Hyderab...
# 3  Bangalore/Bengaluru, Hyderabad/Secunderabad, M...
# 4  Bangalore/Bengaluru, Noida, Kolkata, Mumbai, H...
# 5                        Bangalore/Bengaluru, Mumbai
# ...

# %%
#:QUESTION 3 In this question you have to scrape data using the filters available on the webpage as shown below:

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
driver.get(' https://www.naukri.com/')

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Scientist')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
Job_name=[]
Job_location=[]
Salary=[]
company_name=[]
experience_required=[]

# %%
Jobname_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in Jobname_tags[0:10]:
    Jobname=i.text
    Job_name.append(Jobname)
    
location_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/i')
for i in location_tags[0:10]:
    location=i.text
    Job_location.append(location)
    
salary_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/i')
for i in salary_tags[0:10]:
    salary=i.text
    Salary.append(salary)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(Job_name),len(Job_location),len(Salary),len(company_name),len(experience_required))
# Out:
# 10 1 1 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':Job_name,'Location':Job_location,'SALARY':Salary,'Organization':company_name,'Experience':experience_required})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [198], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df=pd.DataFrame({'Title':Job_name,'Location':Job_location,'SALARY':Salary,'Organization':company_name,'Experience':experience_required})
#       3 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# ...

# %%
# QUESTION 4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:

# %%
driver=webdriver.Chrome(r"Chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/')

# %%
search_products=driver.find_element(By.CLASS_NAME,"_3704LK")
search_products.send_keys('sunglasses')

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
Brand_name=[]
product_description=[]
price=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:40]:
    name=i.text
    Brand_name.append(name)
    
product_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in product_tags[0:40]:
    descp=i.text
    product_description.append(descp)
    
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags[0:40]:
    pri=i.text
    price.append(pri)

# %%
print(len(brand_tags),len(product_description),len(price))
# Out:
# 40 40 40

# %%
import pandas as pd
df=pd.DataFrame({'BRAND NAME':Brand_name,'PRODUCT DESCP':product_description,'PRICE':price})
df
# Out:
#            BRAND NAME                                      PRODUCT DESCP PRICE
# 0      ROZZETTA CRAFT  UV Protection, Gradient Rectangular Sunglasses...  ₹423
# 1      ROZZETTA CRAFT  UV Protection, Gradient Round Sunglasses (Free...  ₹391
# 2            Fastrack   UV Protection Rectangular Sunglasses (Free Size)  ₹439
# 3            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)  ₹649
# 4              PIRASO              UV Protection Aviator Sunglasses (58)  ₹274
# 5            Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...  ₹489
# 6              PIRASO              UV Protection Aviator Sunglasses (54)  ₹208
# 7      ROZZETTA CRAFT  UV Protection, Gradient Rectangular Sunglasses...  ₹377
# 8            Fastrack       UV Protection Aviator Sunglasses (Free Size)  ₹599
# 9            Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...  ₹479
# 10             PIRASO       UV Protection Aviator Sunglasses (Free Size)  ₹268
# ...

# %%
Brand_name=[]
product_description=[]
price=[]

# %%
start=0
end=2
for i in range(start,end):
    name=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in name:
        Brand_name.append(i.text)
for i in range(start,end):
    description=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in description:
        product_description.append(i.text)
        
for i in range(start,end):
    pri=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in pri:
        price.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="ge-49M"]')
    next_button.click()
    time.sleep(2)

# %%
len(Brand_name)
# Out:
# 80

# %%
len(product_description)
# Out:
# 80

# %%
len(price)
# Out:
# 80

# %%
import pandas as pd
df1=pd.DataFrame({'Brand':Brand_name,'PRODUCT DESCP':product_description,'PRICE':price})
df1
# Out:
#             Brand                                      PRODUCT DESCP   PRICE
# 0        Fastrack   UV Protection Rectangular Sunglasses (Free Size)    ₹439
# 1        Fastrack      UV Protection Wayfarer Sunglasses (Free Size)    ₹649
# 2          PIRASO              UV Protection Aviator Sunglasses (58)    ₹274
# 3        Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...    ₹489
# 4          PIRASO              UV Protection Aviator Sunglasses (54)    ₹208
# ..            ...                                                ...     ...
# 75  VINCENT CHASE  by Lenskart Polarized, UV Protection Round Sun...    ₹499
# 76         PIRASO           UV Protection Over-sized Sunglasses (60)  ₹1,429
# 77     EYELLUSION  Night Vision, Polarized, UV Protection, Riding...    ₹185
# 78          NuVew   UV Protection, Mirrored Wayfarer Sunglasses (58)     ₹99
# 79         PIRASO           UV Protection Over-sized Sunglasses (65)    ₹499
#
# [80 rows x 3 columns]

# %%
Brand_name=[]
product_description=[]
price=[]

# %%
start=0
end=3
for i in range(start,end):
    name=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in name[0:35]:
        Brand_name.append(i.text)
for i in range(start,end):
    description=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in description[0:35]:
        product_description.append(i.text)
        
for i in range(start,end):
    pri=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in pri[0:35]:
        price.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="ge-49M"]')
    next_button.click()
    time.sleep(3)

# %%
print(len(Brand_name),len(product_description),len(price))
# Out:
# 105 105 105

# %%
import pandas as pandas 
df2=pd.DataFrame({'Brand':Brand_name,'PRODUCT':product_description,'PRICE':price})
df2
# Out:
#               Brand                                            PRODUCT PRICE
# 0    ROZZETTA CRAFT  UV Protection, Gradient Round Sunglasses (Free...  ₹391
# 1    ROZZETTA CRAFT  UV Protection, Gradient Rectangular Sunglasses...  ₹377
# 2          Fastrack   UV Protection Rectangular Sunglasses (Free Size)  ₹439
# 3          Fastrack      UV Protection Wayfarer Sunglasses (Free Size)  ₹649
# 4            PIRASO              UV Protection Aviator Sunglasses (58)  ₹274
# ..              ...                                                ...   ...
# 100         Anemone  UV Protection, Gradient Rectangular, Spectacle...  ₹356
# 101           NuVew  UV Protection Over-sized, Wayfarer Sunglasses ...  ₹899
# 102           NuVew              UV Protection Aviator Sunglasses (57)  ₹129
# 103          PIRASO              UV Protection Aviator Sunglasses (54)  ₹212
# 104          PIRASO            UV Protection Butterfly Sunglasses (60)  ₹290
#
# [105 rows x 3 columns]
